# %%
# !nvidia-smi
# Out:
# Mon Jun  5 09:30:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 440.33.01    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:06:00.0 Off |                    0 |
# | N/A   38C    P0    56W / 300W |  30209MiB / 32510MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  Off  | 00000000:07:00.0 Off |                    0 |
# | N/A   39C    P0    56W / 300W |  31147MiB / 32510MiB |      0%      Default |
# ...

# %%
# !python ./main.py --gpu 3 --N 2
# Out:
# device : cuda:3
# parllel: 3
# -------PMP HMC Optimizer------
#   0%|                                                 | 0/30000 [00:00<?, ?it/s]epoch 0 loss =  8.808372497558594
# train_acc: 0.06335
# test_acc: 0.107
#   0%|                                      | 50/30000 [00:07<1:14:05,  6.74it/s]epoch 50 loss =  8.986485481262207
# train_acc: 0.11021666666666667
# test_acc: 0.1448
#   0%|1                                    | 100/30000 [00:15<1:15:05,  6.64it/s]epoch 100 loss =  7.113378524780273
# train_acc: 0.2664
# test_acc: 0.2976
#   0%|1                                    | 150/30000 [00:22<1:14:14,  6.70it/s]epoch 150 loss =  4.275700569152832
# train_acc: 0.37185
# test_acc: 0.2897
#   1%|2                                    | 200/30000 [00:30<1:13:59,  6.71it/s]epoch 200 loss =  4.541518688201904
# train_acc: 0.4068
# test_acc: 0.4124
#   1%|3                                    | 250/30000 [00:37<1:14:07,  6.69it/s]epoch 250 loss =  3.7325568199157715
# ...
